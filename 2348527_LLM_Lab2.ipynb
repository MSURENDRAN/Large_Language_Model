# %% [markdown]
# <a href="https://colab.research.google.com/github/MSURENDRAN/Large_Language_Model/blob/main/2348527_LLM_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Collecting langchain
#   Downloading langchain-0.2.8-py3-none-any.whl (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.6/987.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.19 (from langchain)
#   Downloading langchain_core-0.2.19-py3-none-any.whl (366 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.5/366.5 kB 9.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.86-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.19->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.19->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.19->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.8 langchain-core-0.2.19 langchain-text-splitters-0.2.2 langsmith-0.1.86 orjson-3.10.6
# Collecting langchain-groq
#   Downloading langchain_groq-0.1.6-py3-none-any.whl (14 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Downloading groq-0.9.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.2.19)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from groq<1,>=0.4.1->langchain-groq)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (0.1.86)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (8.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.0.7)
# Installing collected packages: h11, httpcore, httpx, groq, langchain-groq
# Successfully installed groq-0.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 langchain-groq-0.1.6

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is football')
# Out:
# "Football, also known as soccer in some countries, is a team sport played with a ball between two teams of eleven players each. \n\nHere's a breakdown:\n\n**Objective:**\n\nThe objective of the game is to score by getting the ball into the opposing team's goal. \n\n**Gameplay:**\n\n* Players use their feet, head, and chest to control and pass the ball. \n* Hands and arms are generally not allowed (except for the goalkeeper within their penalty area).\n* The team with the most goals at the end of the game wins.\n\n**Key Features:**\n\n* **Global Popularity:** Football is the most popular sport in the world, with billions of fans and players.\n* **Physical and Skill-Based:** It requires a combination of strength, speed, agility, endurance, and technical skills.\n* **Strategic Complexity:** Teams employ various tactics and formations to outmaneuver opponents.\n* **International Competitions:** Major tournaments like the FIFA World Cup and UEFA Champions League draw massive global attention.\n* **Diverse Playing Styles:**  Different teams and leagues emphasize different styles of play, such as attacking, defensive, or possession-based football.\n\n**Basic Rules:**\n\n* **Offside:** A player is offside if they are closer to the opponent's goal line than both the ball and the second-to-last defender when the ball is played to them.\n* **Fouls:** Illegal actions like tripping, pushing, or handling the ball (except for the goalkeeper) result in free kicks or penalties.\n* **Throw-ins:** When the ball goes out of bounds on the sidelines, it is thrown back into play by a player from the opposing team.\n* **Corner Kicks:** When the defending team kicks the ball over their own goal line, the attacking team gets a corner kick from the corner of the field.\n* **Goal Kicks:** When the attacking team kicks the ball over the defending team's goal line, the defending team gets a goal kick from inside their penalty area.\n\n**Learning More:**\n\nIf you want to learn more about football, there are countless resources available online and in libraries. You can watch games, read articles, or even try playing yourself!\n\n\n\n"

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
tell me about football
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# Ah, football!  It's hard to sum up such a beloved sport in a short answer, but here's a taste:
#
# **Football, or soccer as it's known in some parts of the world, is a team sport played with a ball between two teams of 11 players.**
#
# Here are some key things to know:
#
# * **Objective:** The goal is to score by getting the ball into the opponent's goal.
# * **Gameplay:** Players use their feet, heads, and chests to control and pass the ball.  Hands and arms are only allowed for the goalkeeper within their penalty area.
# * **Popularity:** It's the most popular sport globally, with millions of fans and players worldwide.
# * **Major Tournaments:**  The FIFA World Cup is the most prestigious international tournament, held every four years. Other major competitions include the UEFA Champions League (Europe), the Copa América (South America), and the African Cup of Nations.
# * **Skills:** Football requires a blend of technical skills (dribbling, passing, shooting), tactical awareness (positioning, strategy), and physical fitness (speed, endurance, strength).
#
# **Want to know more about a specific aspect of football?** Maybe you're curious about:
#
# * **History of the sport**
# * **Different leagues and teams**
# * **Famous players**
# * **Rules and regulations**
# * **How to play**
#
#
# Just let me know!

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma-7b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is football')
# Out:
# "**Football** is a team sport in which two teams of eleven players each compete to score points by carrying or passing the ball into the opponent's end zone.\n\n**Gameplay:**\n\n* The game is played on a rectangular field with end zones at each end.\n* Each team has four downs to gain at least 10 yards to advance the ball down the field.\n* The offense attempts to score points by carrying or passing the ball into the end zone.\n* The defense tries to prevent the offense from scoring points and to score points for their team.\n\n**Objective:**\n\n* The goal of the game is to score more points than the opponent.\n* Points are scored by:\n    * Touchdowns (6 points)\n    * Field goals (3 points)\n    * Safety (2 points)\n\n**Key Elements:**\n\n* **Passing:** Quarterbacks throw the ball to receivers.\n* **Rushing:** Running backs or quarterbacks carry the ball upfield.\n* **Blocking:** Offensive linemen create openings in the line of scrimmage to allow running backs or quarterbacks to carry or pass the ball.\n* **Tackling:** Defensive players try to tackle the ball carrier or ball handler to stop them from scoring.\n\n**Variations:**\n\n* **American Football:** The most popular variant in the United States and Canada.\n* **Canadian Football:** Played with a larger field and more scoring opportunities.\n* **Rugby Football:** Played without a defined boundary, with emphasis on running and kicking.\n\n**Popularity:**\n\nFootball is one of the most popular sports in the world, with passionate fans and a rich history. It is a major cultural event in many countries, and professional leagues exist in many regions."

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is football')
# Out:
# "Football, also known as soccer in some countries, is a team sport played with a ball between two teams of eleven players. \n\nHere's a breakdown:\n\n**Objective:**\n\nThe objective of the game is to score by getting the ball into the opposing team's goal.\n\n**Gameplay:**\n\n* Players use their feet, heads, and chests to control and pass the ball.\n* Hands and arms are generally not allowed, except for the goalkeeper within their penalty area.\n* The team with the most goals at the end of the game wins.\n\n**Key Features:**\n\n* **Global Popularity:** Football is the most popular sport in the world, with billions of fans and players.\n* **Physicality and Skill:**  It requires a combination of strength, speed, agility, and technical skill.\n* **Strategy and Tactics:** Teams employ various formations and strategies to outmaneuver opponents.\n* **International Competitions:** Major tournaments like the FIFA World Cup and UEFA Champions League attract global attention.\n\n**Basic Rules:**\n\n* **Offside:** A player is offside if they are closer to the opponent's goal line than both the ball and the second-to-last defender when the ball is played to them.\n* **Fouls:** Illegal actions like tripping, pushing, or handling the ball (except for the goalkeeper) result in fouls.\n* **Free Kicks and Penalties:** Fouls can lead to free kicks for the opposing team, or a penalty kick if the foul occurs inside the penalty area.\n* **Yellow and Red Cards:** Players can receive yellow cards (warnings) for misconduct and red cards (expulsions) for serious offenses.\n\n**Enjoying Football:**\n\n* **Watching Games:** Football matches are exciting to watch live or on television.\n* **Playing the Sport:** You can join a local team or play recreationally with friends.\n* **Supporting a Team:** Many people develop strong allegiances to their favorite clubs or national teams.\n\n\n\nLet me know if you have any other questions about football!\n\n"

# %% [markdown]
# From Gemini

# %% [markdown]
# ![Screenshot 2024-07-16 122625.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 122657.png](data:image/png;base64,...)
